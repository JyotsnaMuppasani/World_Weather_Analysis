# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs_zip = zip(lats, lngs)
lat_lngs = lat_lngs_zip

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
lat_lngs_zip

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]      
        city_description = city_weather["weather"][0]["description"] 
        
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | klaksvik
# Processing Record 4 of Set 1 | manokwari
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | westport
# Processing Record 7 of Set 1 | avarua
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | bougouni
# Processing Record 10 of Set 1 | vostok
# Processing Record 11 of Set 1 | tabou
# Processing Record 12 of Set 1 | ilulissat
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | burgeo
# Processing Record 15 of Set 1 | rurrenabaque
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | boa vista
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | kaitangata
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | hofn
# Processing Record 29 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 1 | clyde river
# Processing Record 31 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 1 | itaituba
# Processing Record 33 of Set 1 | sobolevo
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | namtsy
# Processing Record 39 of Set 1 | laje
# Processing Record 40 of Set 1 | viedma
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | georgiyevka
# Processing Record 43 of Set 1 | kalemie
# Processing Record 44 of Set 1 | tasiilaq
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | hualmay
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | aurora
# Processing Record 49 of Set 1 | yenagoa
# Processing Record 50 of Set 1 | longyearbyen
# Processing Record 1 of Set 2 | la romana
# Processing Record 2 of Set 2 | mogoytuy
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | brownsville
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | partapur
# Processing Record 8 of Set 2 | tabuk
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | carnarvon
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | brisbane
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | pathein
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | mahebourg
# Processing Record 20 of Set 2 | pacific grove
# Processing Record 21 of Set 2 | padang
# Processing Record 22 of Set 2 | nakusp
# Processing Record 23 of Set 2 | birjand
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 28 of Set 2 | ahipara
# Processing Record 29 of Set 2 | corn island
# Processing Record 30 of Set 2 | along
# Processing Record 31 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 32 of Set 2 | namatanai
# Processing Record 33 of Set 2 | gijon
# Processing Record 34 of Set 2 | benguela
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | epinal
# Processing Record 37 of Set 2 | kuala terengganu
# Processing Record 38 of Set 2 | hasaki
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | grand gaube
# Processing Record 41 of Set 2 | dikson
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 2 | zhangye
# Processing Record 45 of Set 2 | livny
# Processing Record 46 of Set 2 | boyolangu
# Processing Record 47 of Set 2 | haines junction
# Processing Record 48 of Set 2 | stornoway
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | nikolskoye
# Processing Record 2 of Set 3 | codrington
# Processing Record 3 of Set 3 | cidreira
# Processing Record 4 of Set 3 | noumea
# Processing Record 5 of Set 3 | jamestown
# Processing Record 6 of Set 3 | san patricio
# Processing Record 7 of Set 3 | khandyga
# Processing Record 8 of Set 3 | hermanus
# Processing Record 9 of Set 3 | port shepstone
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | tura
# Processing Record 12 of Set 3 | lunenburg
# Processing Record 13 of Set 3 | kondopoga
# Processing Record 14 of Set 3 | copiapo
# Processing Record 15 of Set 3 | opuwo
# Processing Record 16 of Set 3 | auki
# Processing Record 17 of Set 3 | kavieng
# Processing Record 18 of Set 3 | marrakesh
# Processing Record 19 of Set 3 | puerto suarez
# Processing Record 20 of Set 3 | sao filipe
# Processing Record 21 of Set 3 | yar-sale
# Processing Record 22 of Set 3 | saint anthony
# Processing Record 23 of Set 3 | flinders
# Processing Record 24 of Set 3 | rimbey
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | asau
# Processing Record 27 of Set 3 | aporawan
# City not found. Skipping...
# Processing Record 28 of Set 3 | flin flon
# Processing Record 29 of Set 3 | vao
# Processing Record 30 of Set 3 | korem
# Processing Record 31 of Set 3 | mezen
# Processing Record 32 of Set 3 | walvis bay
# Processing Record 33 of Set 3 | yerbogachen
# Processing Record 34 of Set 3 | ancud
# Processing Record 35 of Set 3 | sao jose de ribamar
# Processing Record 36 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | kedrovyy
# Processing Record 39 of Set 3 | bluff
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | kudahuvadhoo
# Processing Record 43 of Set 3 | khorixas
# Processing Record 44 of Set 3 | ballina
# Processing Record 45 of Set 3 | praia da vitoria
# Processing Record 46 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 47 of Set 3 | quelimane
# Processing Record 48 of Set 3 | fairbanks
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | kamensk-uralskiy
# Processing Record 1 of Set 4 | burica
# City not found. Skipping...
# Processing Record 2 of Set 4 | esna
# Processing Record 3 of Set 4 | yinchuan
# Processing Record 4 of Set 4 | kahului
# Processing Record 5 of Set 4 | sayyan
# Processing Record 6 of Set 4 | aswan
# Processing Record 7 of Set 4 | uyemskiy
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | souillac
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | moron
# Processing Record 12 of Set 4 | sao jose da coroa grande
# Processing Record 13 of Set 4 | port-gentil
# Processing Record 14 of Set 4 | santa rosa
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | touros
# Processing Record 17 of Set 4 | camana
# Processing Record 18 of Set 4 | ossora
# Processing Record 19 of Set 4 | bukama
# Processing Record 20 of Set 4 | severo-kurilsk
# Processing Record 21 of Set 4 | beyneu
# Processing Record 22 of Set 4 | saskylakh
# Processing Record 23 of Set 4 | nhulunbuy
# Processing Record 24 of Set 4 | alepe
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | novyy urengoy
# Processing Record 29 of Set 4 | sept-iles
# Processing Record 30 of Set 4 | norman wells
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | te anau
# Processing Record 33 of Set 4 | timmins
# Processing Record 34 of Set 4 | takoradi
# Processing Record 35 of Set 4 | aras
# Processing Record 36 of Set 4 | mbandaka
# Processing Record 37 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 4 | santa catarina de tepehuanes
# Processing Record 39 of Set 4 | bandarbeyla
# Processing Record 40 of Set 4 | dhidhdhoo
# Processing Record 41 of Set 4 | faanui
# Processing Record 42 of Set 4 | batticaloa
# Processing Record 43 of Set 4 | mbanza-ngungu
# Processing Record 44 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 4 | lavrentiya
# Processing Record 46 of Set 4 | surgut
# Processing Record 47 of Set 4 | goya
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | tiarei
# Processing Record 50 of Set 4 | lasa
# Processing Record 1 of Set 5 | ulladulla
# Processing Record 2 of Set 5 | methoni
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | valleyview
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | evansville
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | tawzar
# City not found. Skipping...
# Processing Record 9 of Set 5 | joao pinheiro
# Processing Record 10 of Set 5 | aloleng
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | bilma
# Processing Record 13 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 14 of Set 5 | mount gambier
# Processing Record 15 of Set 5 | sungairaya
# Processing Record 16 of Set 5 | cardston
# Processing Record 17 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 5 | thinadhoo
# Processing Record 20 of Set 5 | kyabe
# Processing Record 21 of Set 5 | constitucion
# Processing Record 22 of Set 5 | guerrero negro
# Processing Record 23 of Set 5 | chumikan
# Processing Record 24 of Set 5 | portland
# Processing Record 25 of Set 5 | tual
# Processing Record 26 of Set 5 | ketchikan
# Processing Record 27 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 5 | khanu woralaksaburi
# Processing Record 29 of Set 5 | vadgaon
# Processing Record 30 of Set 5 | talcahuano
# Processing Record 31 of Set 5 | valparaiso
# Processing Record 32 of Set 5 | goure
# Processing Record 33 of Set 5 | palafrugell
# Processing Record 34 of Set 5 | zyryanka
# Processing Record 35 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 5 | port lincoln
# Processing Record 37 of Set 5 | tarbagatay
# Processing Record 38 of Set 5 | inirida
# Processing Record 39 of Set 5 | conceicao do araguaia
# Processing Record 40 of Set 5 | kollumerland
# City not found. Skipping...
# Processing Record 41 of Set 5 | vardo
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | tukrah
# Processing Record 44 of Set 5 | torbay
# Processing Record 45 of Set 5 | faya
# Processing Record 46 of Set 5 | celestun
# Processing Record 47 of Set 5 | jacareacanga
# Processing Record 48 of Set 5 | alice springs
# Processing Record 49 of Set 5 | luis correia
# Processing Record 50 of Set 5 | la ronge
# Processing Record 1 of Set 6 | lebu
# Processing Record 2 of Set 6 | sorland
# Processing Record 3 of Set 6 | kaeo
# Processing Record 4 of Set 6 | nome
# Processing Record 5 of Set 6 | umm lajj
# Processing Record 6 of Set 6 | whitehorse
# Processing Record 7 of Set 6 | nador
# Processing Record 8 of Set 6 | moree
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | oshawa
# Processing Record 11 of Set 6 | batagay
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | cravo norte
# Processing Record 14 of Set 6 | lethem
# Processing Record 15 of Set 6 | neiafu
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | xudat
# Processing Record 18 of Set 6 | susanville
# Processing Record 19 of Set 6 | ptichye
# Processing Record 20 of Set 6 | bambous virieux
# Processing Record 21 of Set 6 | leicester
# Processing Record 22 of Set 6 | kelowna
# Processing Record 23 of Set 6 | muroto
# Processing Record 24 of Set 6 | san andres
# Processing Record 25 of Set 6 | mitu
# Processing Record 26 of Set 6 | luena
# Processing Record 27 of Set 6 | caxito
# Processing Record 28 of Set 6 | deputatskiy
# Processing Record 29 of Set 6 | luderitz
# Processing Record 30 of Set 6 | tiksi
# Processing Record 31 of Set 6 | laguna
# Processing Record 32 of Set 6 | hithadhoo
# Processing Record 33 of Set 6 | bonthe
# Processing Record 34 of Set 6 | urumqi
# Processing Record 35 of Set 6 | grindavik
# Processing Record 36 of Set 6 | thompson
# Processing Record 37 of Set 6 | grafton
# Processing Record 38 of Set 6 | ambovombe
# Processing Record 39 of Set 6 | aklavik
# Processing Record 40 of Set 6 | mayumba
# Processing Record 41 of Set 6 | bonfim
# Processing Record 42 of Set 6 | kloulklubed
# Processing Record 43 of Set 6 | kodiak
# Processing Record 44 of Set 6 | letpadan
# Processing Record 45 of Set 6 | chuy
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | narsaq
# Processing Record 48 of Set 6 | terrace bay
# Processing Record 49 of Set 6 | coracora
# Processing Record 50 of Set 6 | bilibino
# Processing Record 1 of Set 7 | anisoc
# Processing Record 2 of Set 7 | soroca
# Processing Record 3 of Set 7 | san pedro
# Processing Record 4 of Set 7 | sandnessjoen
# Processing Record 5 of Set 7 | half moon bay
# Processing Record 6 of Set 7 | sotouboua
# Processing Record 7 of Set 7 | lushunkou
# City not found. Skipping...
# Processing Record 8 of Set 7 | palu
# Processing Record 9 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 10 of Set 7 | manaira
# Processing Record 11 of Set 7 | quatre cocos
# Processing Record 12 of Set 7 | mareeba
# Processing Record 13 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 7 | bitung
# Processing Record 15 of Set 7 | andra
# Processing Record 16 of Set 7 | conde
# Processing Record 17 of Set 7 | santa cruz
# Processing Record 18 of Set 7 | pringsewu
# Processing Record 19 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 7 | tucurui
# Processing Record 21 of Set 7 | khudumelapye
# Processing Record 22 of Set 7 | ormond beach
# Processing Record 23 of Set 7 | tevaitoa
# Processing Record 24 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 7 | anori
# Processing Record 26 of Set 7 | abnub
# Processing Record 27 of Set 7 | oparino
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | rocha
# Processing Record 30 of Set 7 | labuhan
# Processing Record 31 of Set 7 | santeramo in colle
# Processing Record 32 of Set 7 | diamantino
# Processing Record 33 of Set 7 | kennebunk
# Processing Record 34 of Set 7 | penzance
# Processing Record 35 of Set 7 | pital
# Processing Record 36 of Set 7 | lixourion
# Processing Record 37 of Set 7 | tungi
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 7 | smolyaninovo
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | shelburne
# Processing Record 43 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 7 | funadhoo
# Processing Record 45 of Set 7 | novikovo
# Processing Record 46 of Set 7 | port blair
# Processing Record 47 of Set 7 | pangkalanbuun
# Processing Record 48 of Set 7 | evensk
# Processing Record 49 of Set 7 | hasanpur
# Processing Record 50 of Set 7 | itarema
# Processing Record 1 of Set 8 | toro
# Processing Record 2 of Set 8 | wagar
# Processing Record 3 of Set 8 | ternate
# Processing Record 4 of Set 8 | qafsah
# City not found. Skipping...
# Processing Record 5 of Set 8 | shepsi
# Processing Record 6 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 7 of Set 8 | sambava
# Processing Record 8 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 9 of Set 8 | ust-ishim
# Processing Record 10 of Set 8 | la solana
# Processing Record 11 of Set 8 | ostrovnoy
# Processing Record 12 of Set 8 | vestmannaeyjar
# Processing Record 13 of Set 8 | serenje
# Processing Record 14 of Set 8 | mpanda
# Processing Record 15 of Set 8 | belmonte
# Processing Record 16 of Set 8 | san fernando
# Processing Record 17 of Set 8 | corinto
# Processing Record 18 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 8 | kearney
# Processing Record 21 of Set 8 | honningsvag
# Processing Record 22 of Set 8 | sola
# Processing Record 23 of Set 8 | panguna
# Processing Record 24 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 25 of Set 8 | ayan
# Processing Record 26 of Set 8 | cabedelo
# Processing Record 27 of Set 8 | atar
# Processing Record 28 of Set 8 | igarka
# Processing Record 29 of Set 8 | halifax
# Processing Record 30 of Set 8 | mpophomeni
# Processing Record 31 of Set 8 | lata
# Processing Record 32 of Set 8 | la maddalena
# Processing Record 33 of Set 8 | cap malheureux
# Processing Record 34 of Set 8 | khoy
# Processing Record 35 of Set 8 | bend
# Processing Record 36 of Set 8 | bubaque
# Processing Record 37 of Set 8 | hastings
# Processing Record 38 of Set 8 | mantua
# Processing Record 39 of Set 8 | bayangol
# Processing Record 40 of Set 8 | mopipi
# Processing Record 41 of Set 8 | broome
# Processing Record 42 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 43 of Set 8 | qui nhon
# Processing Record 44 of Set 8 | lakatoro
# Processing Record 45 of Set 8 | oxford
# Processing Record 46 of Set 8 | suntar
# Processing Record 47 of Set 8 | umea
# Processing Record 48 of Set 8 | esperance
# Processing Record 49 of Set 8 | safaga
# Processing Record 50 of Set 8 | katsuura
# Processing Record 1 of Set 9 | itapuranga
# Processing Record 2 of Set 9 | kruisfontein
# Processing Record 3 of Set 9 | mount isa
# Processing Record 4 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 9 | sarh
# Processing Record 6 of Set 9 | khani
# Processing Record 7 of Set 9 | saint john
# Processing Record 8 of Set 9 | byron bay
# Processing Record 9 of Set 9 | summerville
# Processing Record 10 of Set 9 | sibiti
# Processing Record 11 of Set 9 | kurchum
# Processing Record 12 of Set 9 | altamont
# Processing Record 13 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 9 | sur
# Processing Record 15 of Set 9 | brookhaven
# Processing Record 16 of Set 9 | charlestown
# Processing Record 17 of Set 9 | makakilo city
# Processing Record 18 of Set 9 | ankazoabo
# Processing Record 19 of Set 9 | peniche
# Processing Record 20 of Set 9 | shimoda
# Processing Record 21 of Set 9 | suhbaatar
# Processing Record 22 of Set 9 | jiazi
# Processing Record 23 of Set 9 | asfi
# Processing Record 24 of Set 9 | kencong
# Processing Record 25 of Set 9 | kisangani
# Processing Record 26 of Set 9 | banda aceh
# Processing Record 27 of Set 9 | ostroleka
# Processing Record 28 of Set 9 | yayva
# Processing Record 29 of Set 9 | broken hill
# Processing Record 30 of Set 9 | arlit
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | irpa irpa
# Processing Record 33 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 9 | axim
# Processing Record 35 of Set 9 | mehamn
# Processing Record 36 of Set 9 | kiama
# Processing Record 37 of Set 9 | gornyy
# Processing Record 38 of Set 9 | chone
# Processing Record 39 of Set 9 | itoman
# Processing Record 40 of Set 9 | la rioja
# Processing Record 41 of Set 9 | tahe
# Processing Record 42 of Set 9 | san joaquin
# Processing Record 43 of Set 9 | lorengau
# Processing Record 44 of Set 9 | dunmore town
# Processing Record 45 of Set 9 | yeppoon
# Processing Record 46 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 9 | sharjah
# Processing Record 48 of Set 9 | teahupoo
# Processing Record 49 of Set 9 | hambantota
# Processing Record 50 of Set 9 | ostuni
# Processing Record 1 of Set 10 | puerto escondido
# Processing Record 2 of Set 10 | garissa
# Processing Record 3 of Set 10 | bejar
# Processing Record 4 of Set 10 | taoudenni
# Processing Record 5 of Set 10 | leopold
# Processing Record 6 of Set 10 | mattru
# Processing Record 7 of Set 10 | waipawa
# Processing Record 8 of Set 10 | ust-omchug
# Processing Record 9 of Set 10 | oksfjord
# Processing Record 10 of Set 10 | general roca
# Processing Record 11 of Set 10 | ponta delgada
# Processing Record 12 of Set 10 | nanortalik
# Processing Record 13 of Set 10 | kupang
# Processing Record 14 of Set 10 | kabo
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | gilgil
# City not found. Skipping...
# Processing Record 17 of Set 10 | karratha
# Processing Record 18 of Set 10 | buala
# Processing Record 19 of Set 10 | sorkjosen
# Processing Record 20 of Set 10 | irtyshskiy
# Processing Record 21 of Set 10 | danshui
# Processing Record 22 of Set 10 | andros town
# Processing Record 23 of Set 10 | korla
# Processing Record 24 of Set 10 | knysna
# Processing Record 25 of Set 10 | macas
# Processing Record 26 of Set 10 | afanasyevo
# City not found. Skipping...
# Processing Record 27 of Set 10 | havelock
# Processing Record 28 of Set 10 | progreso
# Processing Record 29 of Set 10 | bose
# Processing Record 30 of Set 10 | vila franca do campo
# Processing Record 31 of Set 10 | tianpeng
# Processing Record 32 of Set 10 | ukiah
# Processing Record 33 of Set 10 | golden
# Processing Record 34 of Set 10 | porto novo
# Processing Record 35 of Set 10 | cherskiy
# Processing Record 36 of Set 10 | huarmey
# Processing Record 37 of Set 10 | pangnirtung
# Processing Record 38 of Set 10 | meadow lake
# Processing Record 39 of Set 10 | port keats
# Processing Record 40 of Set 10 | storslett
# Processing Record 41 of Set 10 | dewas
# Processing Record 42 of Set 10 | imeni poliny osipenko
# Processing Record 43 of Set 10 | tautira
# Processing Record 44 of Set 10 | toftir
# City not found. Skipping...
# Processing Record 45 of Set 10 | jizan
# Processing Record 46 of Set 10 | wangou
# Processing Record 47 of Set 10 | mirnyy
# Processing Record 48 of Set 10 | sagua la grande
# Processing Record 49 of Set 10 | moundou
# Processing Record 50 of Set 10 | deniliquin
# Processing Record 1 of Set 11 | imphal
# Processing Record 2 of Set 11 | mangrol
# Processing Record 3 of Set 11 | rabaul
# Processing Record 4 of Set 11 | velasco ibarra
# Processing Record 5 of Set 11 | marzuq
# Processing Record 6 of Set 11 | egvekinot
# Processing Record 7 of Set 11 | nouadhibou
# Processing Record 8 of Set 11 | conakry
# Processing Record 9 of Set 11 | bijar
# Processing Record 10 of Set 11 | gubbi
# Processing Record 11 of Set 11 | narrabri
# Processing Record 12 of Set 11 | bathsheba
# Processing Record 13 of Set 11 | hoa binh
# Processing Record 14 of Set 11 | ahuimanu
# Processing Record 15 of Set 11 | san benito
# Processing Record 16 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 11 | namibe
# Processing Record 18 of Set 11 | san luis
# Processing Record 19 of Set 11 | manyana
# Processing Record 20 of Set 11 | berlevag
# Processing Record 21 of Set 11 | pendleton
# Processing Record 22 of Set 11 | seoul
# Processing Record 23 of Set 11 | katobu
# Processing Record 24 of Set 11 | kaisiadorys
# Processing Record 25 of Set 11 | ipilan
# Processing Record 26 of Set 11 | bhuban
# Processing Record 27 of Set 11 | nehe
# Processing Record 28 of Set 11 | rasskazovo
# Processing Record 29 of Set 11 | bundaberg
# Processing Record 30 of Set 11 | tagusao
# Processing Record 31 of Set 11 | pierre
# Processing Record 32 of Set 11 | bonavista
# Processing Record 33 of Set 11 | yulara
# Processing Record 34 of Set 11 | cacoal
# Processing Record 35 of Set 11 | viransehir
# Processing Record 36 of Set 11 | simga
# Processing Record 37 of Set 11 | zabaykalsk
# Processing Record 38 of Set 11 | sitka
# Processing Record 39 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 11 | nambucca heads
# Processing Record 41 of Set 11 | erenhot
# Processing Record 42 of Set 11 | nizip
# Processing Record 43 of Set 11 | vavuniya
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | charagua
# Processing Record 46 of Set 11 | sovetskiy
# Processing Record 47 of Set 11 | hvide sande
# Processing Record 48 of Set 11 | lumberton
# Processing Record 49 of Set 11 | komsomolskiy
# Processing Record 50 of Set 11 | mazara del vallo
# Processing Record 1 of Set 12 | surt
# Processing Record 2 of Set 12 | tongchuan
# Processing Record 3 of Set 12 | leshukonskoye
# Processing Record 4 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 12 | shache
# Processing Record 6 of Set 12 | gurskoye
# City not found. Skipping...
# Processing Record 7 of Set 12 | isoka
# Processing Record 8 of Set 12 | novouzensk
# Processing Record 9 of Set 12 | jequie
# Processing Record 10 of Set 12 | veraval
# Processing Record 11 of Set 12 | uray
# Processing Record 12 of Set 12 | kilindoni
# Processing Record 13 of Set 12 | lupiro
# Processing Record 14 of Set 12 | deer lake
# Processing Record 15 of Set 12 | saurimo
# Processing Record 16 of Set 12 | poum
# Processing Record 17 of Set 12 | jacksonville
# Processing Record 18 of Set 12 | kumsi
# Processing Record 19 of Set 12 | san jeronimo
# Processing Record 20 of Set 12 | winnemucca
# Processing Record 21 of Set 12 | leningradskiy
# Processing Record 22 of Set 12 | dodola
# Processing Record 23 of Set 12 | abu samrah
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | luanda
# Processing Record 26 of Set 12 | alofi
# Processing Record 27 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 12 | kang
# Processing Record 29 of Set 12 | fare
# Processing Record 30 of Set 12 | uglegorsk
# Processing Record 31 of Set 12 | cameta
# Processing Record 32 of Set 12 | tabulbah
# City not found. Skipping...
# Processing Record 33 of Set 12 | praia
# Processing Record 34 of Set 12 | salalah
# Processing Record 35 of Set 12 | clonakilty
# Processing Record 36 of Set 12 | mahibadhoo
# Processing Record 37 of Set 12 | cooma
# Processing Record 38 of Set 12 | santa maria
# Processing Record 39 of Set 12 | abadzekhskaya
# Processing Record 40 of Set 12 | slave lake
# Processing Record 41 of Set 12 | manado
# Processing Record 42 of Set 12 | ornskoldsvik
# Processing Record 43 of Set 12 | kulhudhuffushi
# Processing Record 44 of Set 12 | garmsar
# Processing Record 45 of Set 12 | ust-kuyga
# Processing Record 46 of Set 12 | moana
# Processing Record 47 of Set 12 | mukhen
# Processing Record 48 of Set 12 | zwedru
# Processing Record 49 of Set 12 | aykhal
# Processing Record 50 of Set 12 | awbari
# Processing Record 1 of Set 13 | nyurba
# Processing Record 2 of Set 13 | tolaga bay
# Processing Record 3 of Set 13 | rafaela
# Processing Record 4 of Set 13 | yabrud
# Processing Record 5 of Set 13 | san rafael
# Processing Record 6 of Set 13 | comodoro rivadavia
# Processing Record 7 of Set 13 | tshane
# Processing Record 8 of Set 13 | imbituba
# Processing Record 9 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | florianopolis
# Processing Record 12 of Set 13 | husavik
# Processing Record 13 of Set 13 | jinchang
# Processing Record 14 of Set 13 | visnes
# Processing Record 15 of Set 13 | mabaruma
# Processing Record 16 of Set 13 | vung tau
# Processing Record 17 of Set 13 | klyuchi
# Processing Record 18 of Set 13 | praya
# Processing Record 19 of Set 13 | kortkeros
# Processing Record 20 of Set 13 | karsava
# Processing Record 21 of Set 13 | bichena
# Processing Record 22 of Set 13 | mae sai
# Processing Record 23 of Set 13 | sibolga
# Processing Record 24 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 13 | farsund
# Processing Record 26 of Set 13 | beringovskiy
# Processing Record 27 of Set 13 | marsh harbour
# Processing Record 28 of Set 13 | marawi
# Processing Record 29 of Set 13 | naze
# Processing Record 30 of Set 13 | piacabucu
# Processing Record 31 of Set 13 | anito
# Processing Record 32 of Set 13 | galesong
# Processing Record 33 of Set 13 | formosa
# Processing Record 34 of Set 13 | camacupa
# Processing Record 35 of Set 13 | mamit
# Processing Record 36 of Set 13 | malakal
# Processing Record 37 of Set 13 | mastic beach
# Processing Record 38 of Set 13 | algiers
# Processing Record 39 of Set 13 | ilhabela
# Processing Record 40 of Set 13 | puno
# Processing Record 41 of Set 13 | chepareria
# Processing Record 42 of Set 13 | cayenne
# Processing Record 43 of Set 13 | lerwick
# Processing Record 44 of Set 13 | mana
# Processing Record 45 of Set 13 | zomba
# Processing Record 46 of Set 13 | butembo
# Processing Record 47 of Set 13 | agirish
# Processing Record 48 of Set 13 | lesnoy
# Processing Record 49 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 14 | anadyr
# Processing Record 2 of Set 14 | zlitan
# Processing Record 3 of Set 14 | bodden town
# Processing Record 4 of Set 14 | kavaratti
# Processing Record 5 of Set 14 | port hardy
# Processing Record 6 of Set 14 | oranjemund
# Processing Record 7 of Set 14 | reconquista
# Processing Record 8 of Set 14 | gat
# Processing Record 9 of Set 14 | odweyne
# Processing Record 10 of Set 14 | suleja
# Processing Record 11 of Set 14 | hamilton
# Processing Record 12 of Set 14 | carbonia
# Processing Record 13 of Set 14 | trelew
# Processing Record 14 of Set 14 | fukue
# Processing Record 15 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 16 of Set 14 | yumen
# Processing Record 17 of Set 14 | ilebo
# Processing Record 18 of Set 14 | vrangel
# Processing Record 19 of Set 14 | maceio
# Processing Record 20 of Set 14 | ocampo
# Processing Record 21 of Set 14 | venice
# Processing Record 22 of Set 14 | matagami
# Processing Record 23 of Set 14 | maiduguri
# Processing Record 24 of Set 14 | sampit
# Processing Record 25 of Set 14 | geraldton
# Processing Record 26 of Set 14 | brooks
# Processing Record 27 of Set 14 | turtkul
# City not found. Skipping...
# Processing Record 28 of Set 14 | bakchar
# Processing Record 29 of Set 14 | inyonga
# Processing Record 30 of Set 14 | juneau
# Processing Record 31 of Set 14 | moffat
# Processing Record 32 of Set 14 | pachora
# Processing Record 33 of Set 14 | ibra
# Processing Record 34 of Set 14 | safford
# Processing Record 35 of Set 14 | grand-santi
# Processing Record 36 of Set 14 | san carlos
# Processing Record 37 of Set 14 | maslova pristan
# Processing Record 38 of Set 14 | soyo
# Processing Record 39 of Set 14 | coihaique
# Processing Record 40 of Set 14 | saint-ambroise
# Processing Record 41 of Set 14 | ivaipora
# Processing Record 42 of Set 14 | ambon
# Processing Record 43 of Set 14 | bay city
# Processing Record 44 of Set 14 | vidim
# Processing Record 45 of Set 14 | mackay
# Processing Record 46 of Set 14 | dingle
# Processing Record 47 of Set 14 | datong
# Processing Record 48 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 49 of Set 14 | dutse
# Processing Record 50 of Set 14 | madhipura
# Processing Record 1 of Set 15 | healdsburg
# Processing Record 2 of Set 15 | brae
# Processing Record 3 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 4 of Set 15 | port hedland
# Processing Record 5 of Set 15 | ati
# Processing Record 6 of Set 15 | ilam
# Processing Record 7 of Set 15 | vallenar
# Processing Record 8 of Set 15 | shasta lake
# Processing Record 9 of Set 15 | falmouth
# Processing Record 10 of Set 15 | cururupu
# Processing Record 11 of Set 15 | saint-joseph
# Processing Record 12 of Set 15 | hovd
# Processing Record 13 of Set 15 | vuktyl
# Processing Record 14 of Set 15 | kyra
# Processing Record 15 of Set 15 | naryan-mar
# Processing Record 16 of Set 15 | zarakes
# City not found. Skipping...
# Processing Record 17 of Set 15 | blagoyevo
# Processing Record 18 of Set 15 | pueblo
# Processing Record 19 of Set 15 | russell
# Processing Record 20 of Set 15 | dwarka
# Processing Record 21 of Set 15 | henties bay
# Processing Record 22 of Set 15 | charters towers
# Processing Record 23 of Set 15 | zhigansk
# Processing Record 24 of Set 15 | xingyi
# Processing Record 25 of Set 15 | wrexham
# Processing Record 26 of Set 15 | havre-saint-pierre
# Processing Record 27 of Set 15 | nassau
# Processing Record 28 of Set 15 | bako
# Processing Record 29 of Set 15 | kurilsk
# Processing Record 30 of Set 15 | vanavara
# Processing Record 31 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 15 | tanggulangin
# Processing Record 33 of Set 15 | bulembu
# Processing Record 34 of Set 15 | balabac
# Processing Record 35 of Set 15 | mayor pablo lagerenza
# Processing Record 36 of Set 15 | piranhas
# Processing Record 37 of Set 15 | nizhniy ingash
# Processing Record 38 of Set 15 | liuzhou
# Processing Record 39 of Set 15 | klerksdorp
# Processing Record 40 of Set 15 | fortuna
# Processing Record 41 of Set 15 | lompoc
# Processing Record 42 of Set 15 | zaqatala
# Processing Record 43 of Set 15 | lodwar
# Processing Record 44 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 45 of Set 15 | novo aripuana
# Processing Record 46 of Set 15 | margate
# Processing Record 47 of Set 15 | la sarre
# Processing Record 48 of Set 15 | nova granada
# Processing Record 49 of Set 15 | bushehr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 685

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     73.31        74          20
# 1         Ushuaia -54.8000  -68.3000     46.06        57          40
# 2        Klaksvik  62.2266   -6.5890     47.32        89         100
# 3       Manokwari  -0.8667  134.0833     82.04        81          64
# 4        Westport  41.1415  -73.3579     38.75        78         100
# 5          Avarua -21.2078 -159.7750     77.05        83          75
# 6           Kapaa  22.0752 -159.3190     79.12        91           0
# 7        Bougouni  11.4170   -7.4790     70.61        30          76
# 8          Vostok  46.4856  135.8833     -3.35        89         100
# 9           Tabou   4.4230   -7.3528     75.97        89          75
#
#    Wind Speed Country                 Date Current Description
# 0       19.57      ZA  2022-11-30 05:20:22          few clouds
# 1        8.05      AR  2022-11-30 05:20:22    scattered clouds
# 2       17.05      FO  2022-11-30 05:20:22     overcast clouds
# 3        5.50      ID  2022-11-30 05:20:23       broken clouds
# 4        6.91      US  2022-11-30 05:19:30     overcast clouds
# 5        6.91      CK  2022-11-30 05:20:24       broken clouds
# 6        4.61      US  2022-11-30 05:20:24          light rain
# 7        4.41      ML  2022-11-30 05:20:24       broken clouds
# 8       13.67      RU  2022-11-30 05:20:25     overcast clouds
# 9        2.93      CI  2022-11-30 05:20:25          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_col_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_col_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth      ZA -33.9180   25.5701     73.31        74          20
# 1         Ushuaia      AR -54.8000  -68.3000     46.06        57          40
# 2        Klaksvik      FO  62.2266   -6.5890     47.32        89         100
# 3       Manokwari      ID  -0.8667  134.0833     82.04        81          64
# 4        Westport      US  41.1415  -73.3579     38.75        78         100
# 5          Avarua      CK -21.2078 -159.7750     77.05        83          75
# 6           Kapaa      US  22.0752 -159.3190     79.12        91           0
# 7        Bougouni      ML  11.4170   -7.4790     70.61        30          76
# 8          Vostok      RU  46.4856  135.8833     -3.35        89         100
# 9           Tabou      CI   4.4230   -7.3528     75.97        89          75
#
#    Wind Speed Current Description
# 0       19.57          few clouds
# 1        8.05    scattered clouds
# 2       17.05     overcast clouds
# 3        5.50       broken clouds
# 4        6.91     overcast clouds
# 5        6.91       broken clouds
# 6        4.61          light rain
# 7        4.41       broken clouds
# 8       13.67     overcast clouds
# 9        2.93          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "C:/Users/jyots/ucb/hw/World_Weather_Analysis/Weather_Database.ipynb/Weather_Database_starter_code/Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
